# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
from IPython.display import display, HTML
import pandas as pd
from tqdm import tqdm
import numpy as np
import datetime
import scipy.stats as stats
import seaborn as sns


#모든 행, 열 표시
#pd.set_option('display.max_rows', None) 
pd.set_option('display.max_columns', None) 
#디스플레이 설정
display(HTML("<style>.container { width:90% !important; }</style>"))
#matplotlib 한글
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# ----------------------------------------------------------------------------------

# %%
df = pd.read_csv('C:/Users/USER/etri_csv/논문/논문자료_v1.csv')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_5992\428708869.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:/Users/USER/etri_csv/논문/논문자료_v1.csv')

# %%
df.columns
# Out:
# Index(['작업시작시간', '설비', '가동상태', '이력TYPE', '지절', '월', '작업총시간', 'LOT', '제조번호',
#        '지종',
#        ...
#        '320LIC7528:me', '320LIC7529:me', '320LIC7537:me', '320LIC7529:me.1',
#        '320LIC7528:me.1', '320LIC7527:me.1', '320LIC7526:me.1',
#        '320LIC7525:me.1', '320FIA7531:av', '320FIA7535:av'],
#       dtype='object', length=195)

# %%
df['작업시작시간'] = pd.to_datetime(df['작업시작시간'])

# %%
df.set_index('작업시작시간', inplace=True)

# %%
tags = ['HFEMS.MRPAP.01.SH01.PL003.01.A_R',
 'HFEMS.MRPAP.01.SH01.PL003.01.A_S',
 'HFEMS.MRPAP.01.SH01.PL003.01.A_T',
 'HFEMS.MRPAP.01.SH01.PL003.01.HZ',
 'HFEMS.MRPAP.01.SH01.PL003.01.KVARH',
 'HFEMS.MRPAP.01.SH01.PL003.01.KW',
 'HFEMS.MRPAP.01.SH01.PL003.01.KWH',
 'HFEMS.MRPAP.01.SH01.PL003.01.PF',
 'HFEMS.MRPAP.01.SH01.PL003.01.VA',
 'HFEMS.MRPAP.01.SH01.PL003.01.VAR',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_LL_R',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_LL_S',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_LL_T',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_R',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_S',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_T',
 'HFEMS.MRPAP.01.SH01.PL003.02.A_R',
 'HFEMS.MRPAP.01.SH01.PL003.02.A_S',
 'HFEMS.MRPAP.01.SH01.PL003.02.A_T',
 'HFEMS.MRPAP.01.SH01.PL003.02.HZ',
 'HFEMS.MRPAP.01.SH01.PL003.02.KVARH',
 'HFEMS.MRPAP.01.SH01.PL003.02.KW',
 'HFEMS.MRPAP.01.SH01.PL003.02.KWH',
 'HFEMS.MRPAP.01.SH01.PL003.02.PF',
 'HFEMS.MRPAP.01.SH01.PL003.02.VA',
 'HFEMS.MRPAP.01.SH01.PL003.02.VAR',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_LL_R',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_LL_S',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_LL_T',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_R',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_S',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_T',
 'HFEMS.MRPAP.01.SH01.PL003.03.A_R',
 'HFEMS.MRPAP.01.SH01.PL003.03.A_S',
 'HFEMS.MRPAP.01.SH01.PL003.03.A_T',
 'HFEMS.MRPAP.01.SH01.PL003.03.HZ',
 'HFEMS.MRPAP.01.SH01.PL003.03.KVARH',
 'HFEMS.MRPAP.01.SH01.PL003.03.KW',
 'HFEMS.MRPAP.01.SH01.PL003.03.KWH',
 'HFEMS.MRPAP.01.SH01.PL003.03.PF',
 'HFEMS.MRPAP.01.SH01.PL003.03.VA',
 'HFEMS.MRPAP.01.SH01.PL003.03.VAR',
 'HFEMS.MRPAP.01.SH01.PL003.03.V_LL_R',
 'HFEMS.MRPAP.01.SH01.PL003.03.V_LL_S',
 'HFEMS.MRPAP.01.SH01.PL003.03.V_LL_T',
 'HFEMS.MRPAP.01.SH01.PL003.03.V_R',
 'HFEMS.MRPAP.01.SH01.PL003.03.V_S',
 'HFEMS.MRPAP.01.SH01.PL003.03.V_T',
 'HFEMS.MRPAP.01.SH01.PL003.04.A_R',
 'HFEMS.MRPAP.01.SH01.PL003.04.A_S',
 'HFEMS.MRPAP.01.SH01.PL003.04.A_T',
 'HFEMS.MRPAP.01.SH01.PL003.04.HZ',
 'HFEMS.MRPAP.01.SH01.PL003.04.KVARH',
 'HFEMS.MRPAP.01.SH01.PL003.04.KW',
 'HFEMS.MRPAP.01.SH01.PL003.04.KWH',
 'HFEMS.MRPAP.01.SH01.PL003.04.PF',
 'HFEMS.MRPAP.01.SH01.PL003.04.VA',
 'HFEMS.MRPAP.01.SH01.PL003.04.VAR',
 'HFEMS.MRPAP.01.SH01.PL003.04.V_LL_R',
 'HFEMS.MRPAP.01.SH01.PL003.04.V_LL_S',
 'HFEMS.MRPAP.01.SH01.PL003.04.V_LL_T',
 'HFEMS.MRPAP.01.SH01.PL003.04.V_R',
 'HFEMS.MRPAP.01.SH01.PL003.04.V_S',
 'HFEMS.MRPAP.01.SH01.PL003.04.V_T',
 'HFEMS.MRPAP.01.SH01.PL003.05.A_R',
 'HFEMS.MRPAP.01.SH01.PL003.05.A_S',
 'HFEMS.MRPAP.01.SH01.PL003.05.A_T',
 'HFEMS.MRPAP.01.SH01.PL003.05.HZ',
 'HFEMS.MRPAP.01.SH01.PL003.05.KVARH',
 'HFEMS.MRPAP.01.SH01.PL003.05.KW',
 'HFEMS.MRPAP.01.SH01.PL003.05.KWH',
 'HFEMS.MRPAP.01.SH01.PL003.05.PF',
 'HFEMS.MRPAP.01.SH01.PL003.05.VA',
 'HFEMS.MRPAP.01.SH01.PL003.05.VAR',
 'HFEMS.MRPAP.01.SH01.PL003.05.V_LL_R',
 'HFEMS.MRPAP.01.SH01.PL003.05.V_LL_S',
 'HFEMS.MRPAP.01.SH01.PL003.05.V_LL_T',
 'HFEMS.MRPAP.01.SH01.PL003.05.V_R',
 'HFEMS.MRPAP.01.SH01.PL003.05.V_S',
 'HFEMS.MRPAP.01.SH01.PL003.05.V_T',
 'HFEMS.MRPAP.01.SH01.PL003.06.A_R',
 'HFEMS.MRPAP.01.SH01.PL003.06.A_S',
 'HFEMS.MRPAP.01.SH01.PL003.06.A_T',
 'HFEMS.MRPAP.01.SH01.PL003.06.HZ',
 'HFEMS.MRPAP.01.SH01.PL003.06.KVARH',
 'HFEMS.MRPAP.01.SH01.PL003.06.KW',
 'HFEMS.MRPAP.01.SH01.PL003.06.KWH',
 'HFEMS.MRPAP.01.SH01.PL003.06.PF',
 'HFEMS.MRPAP.01.SH01.PL003.06.VA',
 'HFEMS.MRPAP.01.SH01.PL003.06.VAR',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_LL_R',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_LL_S',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_LL_T',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_R',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_S',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_T',
 '320PIC7509:me',
 '320PIC7510:me',
 '320PIC7511:me',
 'PM3-S3SC.opr:me',
 '320PIC7513:me',
 '320PIC7514:me',
 'PM3-S5SC.opr:me',
 '320PIC7524:me',
 '320PIC7533:me',
 '320PIC7544:me',
 '320PIC7505:me',
 '320PIC7506:me',
 '320PIC7507:me',
 '320PIC7508:me',
 '320PDC7516:me',
 '320PDC7518:me',
 '320PDV7519.1:av',
 '320PDC7520:me',
 '320PDV7522.1:av',
 '320HIC7501:av',
 '320TIA7504:av',
 '320TIA7530:av',
 '320TIA7541:av',
 '320TIA7542:av',
 '320TIC7523:me',
 '320PIC7524:me.1',
 '320TIC0004:me',
 '320TIC7540:me',
 '320TIC7545:me',
 'PM3_BASIS_WEIGHT_SP',
 'PM3_BASIS_WEIGHT_SP2',
 'PM3_MOISTURE_SP',
 'PM3_MOISTURE_SP2',
 '329-GIC1002:me',
 '329-PIC7030.A:me',
 '329-PIC7030.B:me',
 '320-PIC0501:me',
 'PM3_WIRE_SPEED',
 'PM3_ASH_PV',
 'PM3_STOCK_CONSISTENCY_PV',
 'PM3_STOCK_FLOW_PV',
 'PM3-JWC1.opr:me',
 'PM3-TSF1.opr:me',
 'PM3-RLS1.opr:me',
 'PM3-TASH.opr:me',
 '320LIC7524:me',
 '320LIC7525:me',
 '320LIC7526:me',
 '320LIC7527:me',
 '320LIC7528:me',
 '320LIC7529:me',
 '320LIC7537:me',
 '320LIC7529:me.1',
 '320LIC7528:me.1',
 '320LIC7527:me.1',
 '320LIC7526:me.1',
 '320LIC7525:me.1',
 '320FIA7531:av',
 '320FIA7535:av']

# %%
df['평량'] = df['평량'].astype(str)

# %%
df['지종(평량)'] = df['지종']+"("+df['평량']+")"

# %%
condition_1 = df['지종(평량)']=='네오★백상(150.0)'
condition_2 = df['지종(평량)']=='네오★스노우화이트기지(81.0)'
condition_3 = df['지종(평량)']=='네오★스노우화이트기지(73.0)'
condition_4 = df['지종(평량)']=='네오★스노우화이트기지(62.0)'
condition_5 = df['지종(평량)']=='네오★스노우화이트기지(103.0)'
condition_6 = df['지종(평량)']=='NEO★MATT 9+ R10기지(172.0)'
condition_7 = df['지종(평량)']=='네오★아트 R10기지(103.0)'
condition_8 = df['지종(평량)']=='네오★아트 R10기지(216.0)'
condition_9 = df['지종(평량)']=='네오★아트기지(198.0)'
condition_10 = df['지종(평량)']=='네오★쇼핑백기지(113.0)'

condition_11 = df['지종(평량)']=='네오★쇼핑백기지(133.0)'
condition_12 = df['지종(평량)']=='네오★라벨기지(67.0)'
condition_13 = df['지종(평량)']=='네오★백상쇼핑백(160.0)'
condition_14 = df['지종(평량)']=='네오★아트 R10기지(67.0)'
condition_15 = df['지종(평량)']=='네오★선함침지(백색)기지(54.0)'
condition_16 = df['지종(평량)']=='네오★아트 R10기지(56.0)'
condition_17 = df['지종(평량)']=='네오★아트 R10기지(77.0)'
condition_18 = df['지종(평량)']=='네오★백상(100.0)'
condition_19 = df['지종(평량)']=='네오★아트기지(134.0)'
condition_20 = df['지종(평량)']=='네오★아트기지(152.0)'

condition_21 = df['지종(평량)']=='네오★아트기지(216.0)'
condition_22 = df['지종(평량)']=='네오★스노우화이트기지(77.0)'
condition_23 = df['지종(평량)']=='네오★스노우화이트 R10기지(67.0)'
condition_24 = df['지종(평량)']=='네오★스노우화이트 R10기지(77.0)'
condition_25 = df['지종(평량)']=='네오★스노우화이트 R10기지(103.0)'
condition_26 = df['지종(평량)']=='네오★승화열전사지기지(65.0)'
condition_27 = df['지종(평량)']=='네오★승화열전사지기지(75.0)'
condition_28 = df['지종(평량)']=='네오★승화열전사지기지(95.0)'
condition_29 = df['지종(평량)']=='네오★승화열전사지(속건형)기지(52.0)'
condition_30 = df['지종(평량)']=='네오★승화열전사지(속건형)기지(62.0)'

condition_31 = df['지종(평량)']=='네오★승화열전사지(속건형)기지(82.0)'
condition_32 = df['지종(평량)']=='네오★승화열(STK-S)기지(85.0)'
condition_33 = df['지종(평량)']=='네오★승화열(STK-S)기지(95.0)'
condition_34 = df['지종(평량)']=='네오★승화열전사(강STKS)기지(95.0)'
condition_35 = df['지종(평량)']=='네오★승화열전사지(QE)기지(87.0)'
condition_36 = df['지종(평량)']=='네오★아트기지(103.0)'
condition_37 = df['지종(평량)']=='네오★아트기지(77.0)'
condition_38 = df['지종(평량)']=='네오★파워쇼핑백기지(93.0)'
condition_39 = df['지종(평량)']=='네오★파워쇼핑백기지(103.0)'
condition_40 = df['지종(평량)']=='네오★파워쇼핑백기지(123.0)'

condition_41 = df['지종(평량)']=='네오★아트기지(62.0)'
condition_42 = df['지종(평량)']=='네오★백상(70.0)'
condition_43 = df['지종(평량)']=='네오★M라벨(P-GLOSS)기지(57.0)'
condition_44 = df['지종(평량)']=='네오★라벨기지(57.0)'
condition_45 = df['지종(평량)']=='네오★라벨기지(77.0)'
condition_46 = df['지종(평량)']=='네오★백상(80.0)'
condition_47 = df['지종(평량)']=='네오★아트기지(81.0)'
condition_48 = df['지종(평량)']=='네오★라벨기지(52.0)'
condition_49 = df['지종(평량)']=='네오★승화열전사원지(100.0)'
condition_50 = df['지종(평량)']=='네오★승화열전사지기지(85.0)'

condition_51 = df['지종(평량)']=='네오★승화열(STK-S)기지(65.0)'
condition_52 = df['지종(평량)']=='네오★승화열전사(약STKS)기지(77.0)'
condition_53 = df['지종(평량)']=='네오★승화열전사지(QE)기지(62.0)'
condition_54 = df['지종(평량)']=='네오★백상쇼핑백(140.0)'
condition_55 = df['지종(평량)']=='네오★파워라벨(S)기지(57.0)'
condition_56 = df['지종(평량)']=='네오★백상쇼핑백(180.0)'
condition_57 = df['지종(평량)']=='네오★그린박리지(D1)기지(115.0)'
condition_58 = df['지종(평량)']=='네오★그린박리지(D1)기지(86.0)'
condition_59 = df['지종(평량)']=='네오★그린스노우화이트기지(62.0)'
condition_60 = df['지종(평량)']=='네오★그린스노우화이트기지(77.0)'

condition_61 = df['지종(평량)']=='네오★백상(PP합지)(80.0)'
condition_62 = df['지종(평량)']=='네오★그린스노우화이트기지(103.0)'
condition_63 = df['지종(평량)']=='네오★스노우화이트 R10기지(56.0)'
condition_64 = df['지종(평량)']=='네오★승화열전사(강STKS)기지(85.0)'
condition_65 = df['지종(평량)']=='네오★아트기지(73.0)'
condition_66 = df['지종(평량)']=='네오★쇼핑백기지(130.0)'
condition_67 = df['지종(평량)']=='네오★백상쇼핑백 PCW40(180.0)'
condition_68 = df['지종(평량)']=='네오★SPEEDJET(라벨)(70.0)'
condition_69 = df['지종(평량)']=='NEO★SPEEDJET(고백색)(90.0)'
condition_70 = df['지종(평량)']=='네오★승화열전사지(속건형)기지(92.0)'

condition_71 = df['지종(평량)']=='네오★박리지(백색)(90.0)'
condition_72 = df['지종(평량)']=='네오★그랜드보드기지(180.0)'
condition_73 = df['지종(평량)']=='네오★그린박리지(S1)기지(67.0)'
condition_74 = df['지종(평량)']=='네오★스노우화이트기지(67.0)'
condition_75 = df['지종(평량)']=='네오★스노우화이트기지(134.0)'
condition_76 = df['지종(평량)']=='네오★스노우화이트기지(152.0)'
condition_77 = df['지종(평량)']=='네오★박리지(백색)(130.0)'
condition_78 = df['지종(평량)']=='네오★박리지(백색)(120.0)'
condition_79 = df['지종(평량)']=='네오★박리지(백색)(100.0)'
condition_80 = df['지종(평량)']=='네오★박리지(백색)(80.0)'

condition_81 = df['지종(평량)']=='네오★박리지(백색)(70.0)'
condition_82 = df['지종(평량)']=='네오★박리지(고백색)(70.0)'
condition_83 = df['지종(평량)']=='네오★아트 R10기지(169.0)'
condition_84 = df['지종(평량)']=='네오★그랜드보드기지(143.0)'
condition_85 = df['지종(평량)']=='네오★그랜드보드기지(162.0)'
condition_86 = df['지종(평량)']=='네오★백상(하이벌크EW)(118.0)'
condition_87 = df['지종(평량)']=='네오★아트기지(169.0)'
condition_88 = df['지종(평량)']=='NEO★SPEEDJET(90.0)'
condition_89 = df['지종(평량)']=='NEO★SPEEDJET(80.0)'
condition_90 = df['지종(평량)']=='NEO★SPEEDJET(70.0)'
condition_91 = df['지종(평량)']=='네오★스노우화이트기지(198.0)'

# %%
for index,conditions in enumerate([condition_1, condition_2, condition_3, condition_4, condition_5, condition_6, condition_7, condition_8, condition_9, 
                                  condition_10, condition_11, condition_12, condition_13, condition_14, condition_15, condition_16, condition_17, condition_18, condition_19,
                                  condition_20, condition_21, condition_22, condition_23, condition_24, condition_25, condition_26, condition_27, condition_28, condition_29,
                                  condition_30, condition_31, condition_32, condition_33, condition_34, condition_35, condition_36, condition_37, condition_38, condition_39,
                                  condition_40, condition_41, condition_42, condition_43, condition_44, condition_45, condition_46, condition_47, condition_48, condition_49,
                                  condition_50, condition_51, condition_52, condition_53, condition_54, condition_55, condition_56, condition_57, condition_58, condition_59,
                                  condition_60, condition_61, condition_62, condition_63, condition_64, condition_65, condition_66, condition_67, condition_68, condition_69,
                                  condition_70, condition_71, condition_72, condition_73, condition_74, condition_75, condition_76, condition_77, condition_78, condition_79,
                                  condition_80, condition_81, condition_82, condition_83, condition_84, condition_85, condition_86, condition_87, condition_88, condition_89,
                                  condition_90, condition_91]):
    df.loc[conditions,['지종(평량)']]=index

# %%
paper1 = df['지종']=='네오★백상'
paper2 = df['지종']=='네오★스노우화이트기지'
paper3 = df['지종']=='NEO★MATT 9+ R10기지'
paper4 = df['지종']=='네오★아트 R10기지'
paper5 = df['지종']=='네오★아트기지'
paper6 = df['지종']=='네오★쇼핑백기지'
paper7 = df['지종']=='네오★라벨기지'
paper8 = df['지종']=='네오★백상쇼핑백'
paper9 = df['지종']=='네오★선함침지(백색)기지'
paper10 = df['지종']=='네오★스노우화이트 R10기지'
paper11 = df['지종']=='네오★승화열전사지기지'
paper12 = df['지종']=='네오★승화열전사지(속건형)기지'
paper13 = df['지종']=='네오★승화열(STK-S)기지'
paper14 = df['지종']=='네오★승화열전사(강STKS)기지'
paper15 = df['지종']=='네오★승화열전사지(QE)기지'
paper16 = df['지종']=='네오★파워쇼핑백기지'
paper17 = df['지종']=='네오★M라벨(P-GLOSS)기지'
paper18 = df['지종']=='네오★승화열전사원지'
paper19 = df['지종']=='네오★승화열전사(약STKS)기지'
paper20 = df['지종']=='네오★파워라벨(S)기지'
paper21 = df['지종']=='네오★그린박리지(D1)기지'
paper22 = df['지종']=='네오★그린스노우화이트기지'
paper23 = df['지종']=='네오★백상(PP합지)'
paper24 = df['지종']=='네오★백상쇼핑백 PCW40'
paper25 = df['지종']=='네오★SPEEDJET(라벨)'
paper26 = df['지종']=='NEO★SPEEDJET(고백색)'
paper27 = df['지종']=='네오★박리지(백색)'
paper28 = df['지종']=='네오★그랜드보드기지'
paper29 = df['지종']=='네오★그린박리지(S1)기지'
paper30 = df['지종']=='네오★박리지(고백색)'
paper31 = df['지종']=='네오★백상(하이벌크EW)'
paper32 = df['지종']=='NEO★SPEEDJET'

# %%
for index,condition in enumerate([paper1,paper2,paper3,paper4,paper5,paper6,paper7,paper8,paper9,paper10,paper11,paper12,paper13,paper14,paper15,paper16,paper17,paper18,paper19,paper20,paper21,paper22,paper23,paper24,paper25,paper26,paper27,paper28,paper29,paper30,paper31,paper32]):
    df.loc[condition,['지종']]=index

# %%
event1 =df['이력TYPE']=='생산'
event2 =df['이력TYPE']=='지종교체'
event3 =df['이력TYPE']=='유효가동'
event4 =df['이력TYPE']=='초출파지'
event5 =df['이력TYPE']=='Press'
event6 =df['이력TYPE']=='평량교체'
event7 =df['이력TYPE']=='Size Press'
event8 =df['이력TYPE']=='계획보수'
event9 =df['이력TYPE']=='설비가동'
event10 =df['이력TYPE']=='Pre-Dryer'
event11 =df['이력TYPE']=='Reel'
event12 =df['이력TYPE']=='After-Dryer'
event13 =df['이력TYPE']=='Calender'
event14 =df['이력TYPE']=='W/W Pit (tank)'
event15 =df['이력TYPE']=='Air Line'
event16 =df['이력TYPE']=='전력부하조정'
event17 =df['이력TYPE']=='설비수리'

# %%
for index,condition in enumerate([event1, event2, event3, event4, event5, event6, event7, event8, event9, event10, event11, event12, event13, event14, event15, event16, event17, ]):
    df.loc[condition,['이력TYPE']]=index

# %%
df[tags]=df[tags].interpolate(method = 'time')

# %%
df.dropna(subset=['설비'], inplace=True)
#df.dropna(axis=1, inplace=True)

# %%
col = [
 '이력TYPE',
 '월',
 '지종',
 '평량',
 '지종(평량)',
 '지폭(규격)',
 'OrderNo',
 '릴No',
 'HFEMS.MRPAP.01.SH01.PL003.01.A_R',
 'HFEMS.MRPAP.01.SH01.PL003.01.A_S',
 'HFEMS.MRPAP.01.SH01.PL003.01.A_T',
 'HFEMS.MRPAP.01.SH01.PL003.01.HZ',
 'HFEMS.MRPAP.01.SH01.PL003.01.KVARH',
 'HFEMS.MRPAP.01.SH01.PL003.01.KW',
 'HFEMS.MRPAP.01.SH01.PL003.01.KWH',
 'HFEMS.MRPAP.01.SH01.PL003.01.PF',
 'HFEMS.MRPAP.01.SH01.PL003.01.VA',
 'HFEMS.MRPAP.01.SH01.PL003.01.VAR',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_LL_R',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_LL_S',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_LL_T',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_R',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_S',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_T',
 'HFEMS.MRPAP.01.SH01.PL003.02.A_R',
 'HFEMS.MRPAP.01.SH01.PL003.02.A_S',
 'HFEMS.MRPAP.01.SH01.PL003.02.A_T',
 'HFEMS.MRPAP.01.SH01.PL003.02.HZ',
 'HFEMS.MRPAP.01.SH01.PL003.02.KVARH',
 'HFEMS.MRPAP.01.SH01.PL003.02.KW',
 'HFEMS.MRPAP.01.SH01.PL003.02.KWH',
 'HFEMS.MRPAP.01.SH01.PL003.02.PF',
 'HFEMS.MRPAP.01.SH01.PL003.02.VA',
 'HFEMS.MRPAP.01.SH01.PL003.02.VAR',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_LL_R',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_LL_S',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_LL_T',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_R',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_S',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_T',
 'HFEMS.MRPAP.01.SH01.PL003.03.A_R',
 'HFEMS.MRPAP.01.SH01.PL003.03.A_S',
 'HFEMS.MRPAP.01.SH01.PL003.03.A_T',
 'HFEMS.MRPAP.01.SH01.PL003.03.HZ',
 'HFEMS.MRPAP.01.SH01.PL003.03.KVARH',
 'HFEMS.MRPAP.01.SH01.PL003.03.KW',
 'HFEMS.MRPAP.01.SH01.PL003.03.KWH',
 'HFEMS.MRPAP.01.SH01.PL003.03.PF',
 'HFEMS.MRPAP.01.SH01.PL003.03.VA',
 'HFEMS.MRPAP.01.SH01.PL003.03.VAR',
 'HFEMS.MRPAP.01.SH01.PL003.03.V_LL_R',
 'HFEMS.MRPAP.01.SH01.PL003.03.V_LL_S',
 'HFEMS.MRPAP.01.SH01.PL003.03.V_LL_T',
 'HFEMS.MRPAP.01.SH01.PL003.03.V_R',
 'HFEMS.MRPAP.01.SH01.PL003.03.V_S',
 'HFEMS.MRPAP.01.SH01.PL003.03.V_T',
 'HFEMS.MRPAP.01.SH01.PL003.04.A_R',
 'HFEMS.MRPAP.01.SH01.PL003.04.A_S',
 'HFEMS.MRPAP.01.SH01.PL003.04.A_T',
 'HFEMS.MRPAP.01.SH01.PL003.04.HZ',
 'HFEMS.MRPAP.01.SH01.PL003.04.KVARH',
 'HFEMS.MRPAP.01.SH01.PL003.04.KW',
 'HFEMS.MRPAP.01.SH01.PL003.04.KWH',
 'HFEMS.MRPAP.01.SH01.PL003.04.PF',
 'HFEMS.MRPAP.01.SH01.PL003.04.VA',
 'HFEMS.MRPAP.01.SH01.PL003.04.VAR',
 'HFEMS.MRPAP.01.SH01.PL003.04.V_LL_R',
 'HFEMS.MRPAP.01.SH01.PL003.04.V_LL_S',
 'HFEMS.MRPAP.01.SH01.PL003.04.V_LL_T',
 'HFEMS.MRPAP.01.SH01.PL003.04.V_R',
 'HFEMS.MRPAP.01.SH01.PL003.04.V_S',
 'HFEMS.MRPAP.01.SH01.PL003.04.V_T',
 'HFEMS.MRPAP.01.SH01.PL003.05.A_R',
 'HFEMS.MRPAP.01.SH01.PL003.05.A_S',
 'HFEMS.MRPAP.01.SH01.PL003.05.A_T',
 'HFEMS.MRPAP.01.SH01.PL003.05.HZ',
 'HFEMS.MRPAP.01.SH01.PL003.05.KVARH',
 'HFEMS.MRPAP.01.SH01.PL003.05.KW',
 'HFEMS.MRPAP.01.SH01.PL003.05.KWH',
 'HFEMS.MRPAP.01.SH01.PL003.05.PF',
 'HFEMS.MRPAP.01.SH01.PL003.05.VA',
 'HFEMS.MRPAP.01.SH01.PL003.05.VAR',
 'HFEMS.MRPAP.01.SH01.PL003.05.V_LL_R',
 'HFEMS.MRPAP.01.SH01.PL003.05.V_LL_S',
 'HFEMS.MRPAP.01.SH01.PL003.05.V_LL_T',
 'HFEMS.MRPAP.01.SH01.PL003.05.V_R',
 'HFEMS.MRPAP.01.SH01.PL003.05.V_S',
 'HFEMS.MRPAP.01.SH01.PL003.05.V_T',
 'HFEMS.MRPAP.01.SH01.PL003.06.A_R',
 'HFEMS.MRPAP.01.SH01.PL003.06.A_S',
 'HFEMS.MRPAP.01.SH01.PL003.06.A_T',
 'HFEMS.MRPAP.01.SH01.PL003.06.HZ',
 'HFEMS.MRPAP.01.SH01.PL003.06.KVARH',
 'HFEMS.MRPAP.01.SH01.PL003.06.KW',
 'HFEMS.MRPAP.01.SH01.PL003.06.KWH',
 'HFEMS.MRPAP.01.SH01.PL003.06.PF',
 'HFEMS.MRPAP.01.SH01.PL003.06.VA',
 'HFEMS.MRPAP.01.SH01.PL003.06.VAR',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_LL_R',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_LL_S',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_LL_T',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_R',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_S',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_T',
 '320PIC7513:me',
 '320PIC7514:me',
 'PM3-S5SC.opr:me',
 '320PIC7533:me',
 '320PIC7544:me',
 '320PIC7505:me',
 '320PIC7506:me',
 '320PDC7516:me',
 '320PDC7520:me',
 '320TIA7542:av',
 '320TIC7545:me',
 'PM3_BASIS_WEIGHT_SP',
 'PM3_BASIS_WEIGHT_SP2',
 'PM3_MOISTURE_SP',
 'PM3_MOISTURE_SP2',
 '320-PIC0501:me',
 'PM3_WIRE_SPEED',
 'PM3_ASH_PV',
 'PM3_STOCK_CONSISTENCY_PV',
 'PM3_STOCK_FLOW_PV',
 'PM3-TASH.opr:me',
 '320LIC7526:me',
 '320LIC7527:me',
 '320LIC7528:me',
 '320LIC7537:me',
 '320LIC7528:me.1',
 '320LIC7527:me.1',
 '320LIC7526:me.1',
 '320FIA7531:av']

# %%
df[col] = df[col].astype(float)

# %% [markdown]
# sns.pairplot(df)
# plt.show()

# %% [markdown]
# sns.pairplot(df, hue='월')

# %% [markdown]
# 월별 상관계수

# %%
df_spearmanr = df

# %%
def correlation_M(month):
    y = df_spearmanr.loc[:, '지절'].values
    temp=pd.DataFrame(index = col, columns=['Corr', 'P-val'])
    for item in col:
        X = df_spearmanr.loc[:, item].values
        
        if (stats.spearmanr(X,y)[1]<0.05) and (stats.spearmanr(X,y)[1]>0.001):
            temp.loc[len[temp], 'Corr'] = stats.spearmanr(X, y)[0]
            temp.loc[len[temp], 'P-val'] = stats.spearmanr(X, y)[1]

    return temp.pivot(['item'], '월', ['Corr','P-val'])

# %%
def correlation_M(month):
    y = df_spearmanr.loc[df_spearmanr['월']==month, '지절'].values
    temp=pd.DataFrame(columns=['월', 'item', 'Corr', 'P-val'])
    for item in col:
        X = df_spearmanr.loc[df_spearmanr['월']==month, item].values
        
        if (stats.spearmanr(X,y)[1]<0.05) and (stats.spearmanr(X,y)[1]>0.001):
            temp.loc[len(temp)] = [month, item, stats.spearmanr(X, y)[0], stats.spearmanr(X, y)[1]]

    return temp.pivot(['item'], '월', ['Corr','P-val'])

# %%
temp = pd.DataFrame()
for i in range(len(list(df_spearmanr['월'].unique()))):
    pivot = correlation(i+1)
    temp = pd.concat([temp, pivot])
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\scipy\stats\stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# C:\Users\USER\anaconda3\lib\site-packages\scipy\stats\stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# C:\Users\USER\anaconda3\lib\site-packages\scipy\stats\stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# C:\Users\USER\anaconda3\lib\site-packages\scipy\stats\stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# ...

# %%
#temp.columns = temp.columns.swaplevel(0, 1)
#temp.sort_index(axis=1, level=0, inplace=True)

# %%
col1 = list(temp.index)

# %%
temp.loc[col1, (slice(None),3)].dropna()
# Out:
#                                      Corr     P-val
# 월                                       3         3
# item
# HFEMS.MRPAP.01.SH01.PL003.01.HZ  0.009846  0.049656
# HFEMS.MRPAP.01.SH01.PL003.02.HZ  0.010009  0.045989
# HFEMS.MRPAP.01.SH01.PL003.01.HZ  0.009846  0.049656
# HFEMS.MRPAP.01.SH01.PL003.02.HZ  0.010009  0.045989
# 320LIC7537:me                   -0.012721  0.011202
# 320PDC7516:me                    0.013157  0.008711
# 320PIC7506:me                   -0.016291  0.001162
# HFEMS.MRPAP.01.SH01.PL003.01.HZ  0.009846  0.049656
# HFEMS.MRPAP.01.SH01.PL003.02.HZ  0.010009  0.045989
# HFEMS.MRPAP.01.SH01.PL003.05.PF -0.014027  0.005165
# 320LIC7537:me                   -0.012721  0.011202
# HFEMS.MRPAP.01.SH01.PL003.01.HZ  0.009846  0.049656
# HFEMS.MRPAP.01.SH01.PL003.02.HZ  0.010009  0.045989
# HFEMS.MRPAP.01.SH01.PL003.01.HZ  0.009846  0.049656
# HFEMS.MRPAP.01.SH01.PL003.02.HZ  0.010009  0.045989
# HFEMS.MRPAP.01.SH01.PL003.01.HZ  0.009846  0.049656
# ...

# %%
import winsound as sd

fr = 2000    # range : 37 ~ 32767
du = 1000     # 1000 ms ==1second
sd.Beep(fr, du)

# %% [markdown]
# 5분 단위 구간별 통계적 요약(표준편차)

# %%
temp1= np.sqrt(df[tags].resample('5T').sum())
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = func(self.values, **kwargs)

# %%
temp2=df.loc[:,['이력TYPE','월', '지절','지종', '평량', '지종(평량)', '지폭(규격)', 'OrderNo', '릴No']]

# %%
 df_5T=pd.merge(temp1, temp2, on=['작업시작시간'], how='left')

# %%
df_5T.dropna(subset=['지종'],inplace=True)

# %%
df_5T = df_5T.loc[:, col]

# %%
df_5T.dropna(inplace=True)

# %%
df_spearmanr = df_5T

# %%
temp = pd.DataFrame()
for i in range(len(list(df_spearmanr['월'].unique()))):
    pivot = correlation(i+1)
    temp = pd.concat([temp, pivot])
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\scipy\stats\stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# C:\Users\USER\anaconda3\lib\site-packages\scipy\stats\stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# C:\Users\USER\anaconda3\lib\site-packages\scipy\stats\stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# C:\Users\USER\anaconda3\lib\site-packages\scipy\stats\stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# ...

# %%
temp
# Out:
#                                      Corr     P-val Corr P-val Corr P-val  \
# 월                                       1         1    2     2    3     3
# item
# 320-PIC0501:me                   0.013357  0.007496  NaN   NaN  NaN   NaN
# 320LIC7527:me                   -0.012896  0.009829  NaN   NaN  NaN   NaN
# 320LIC7527:me.1                 -0.012896  0.009829  NaN   NaN  NaN   NaN
# 320TIC7545:me                    0.013919  0.005328  NaN   NaN  NaN   NaN
# HFEMS.MRPAP.01.SH01.PL003.01.HZ  0.014093  0.004782  NaN   NaN  NaN   NaN
# ...                                   ...       ...  ...   ...  ...   ...
# HFEMS.MRPAP.01.SH01.PL003.04.HZ       NaN       NaN  NaN   NaN  NaN   NaN
# HFEMS.MRPAP.01.SH01.PL003.05.HZ       NaN       NaN  NaN   NaN  NaN   NaN
# PM3-TASH.opr:me                       NaN       NaN  NaN   NaN  NaN   NaN
# PM3_ASH_PV                            NaN       NaN  NaN   NaN  NaN   NaN
# 지종(평량)                                NaN       NaN  NaN   NaN  NaN   NaN
#
# ...

# %%
temp.loc[col1, (slice(None),3)].dropna()
# Out:
#                                      Corr     P-val
# 월                                       3         3
# item
# HFEMS.MRPAP.01.SH01.PL003.01.HZ  0.009846  0.049656
# HFEMS.MRPAP.01.SH01.PL003.02.HZ  0.010009  0.045989
# HFEMS.MRPAP.01.SH01.PL003.01.HZ  0.009846  0.049656
# HFEMS.MRPAP.01.SH01.PL003.02.HZ  0.010009  0.045989
# 320LIC7537:me                   -0.012721  0.011202
# 320PDC7516:me                    0.013157  0.008711
# 320PIC7506:me                   -0.016291  0.001162
# HFEMS.MRPAP.01.SH01.PL003.01.HZ  0.009846  0.049656
# HFEMS.MRPAP.01.SH01.PL003.02.HZ  0.010009  0.045989
# HFEMS.MRPAP.01.SH01.PL003.05.PF -0.014027  0.005165
# 320LIC7537:me                   -0.012721  0.011202
# HFEMS.MRPAP.01.SH01.PL003.01.HZ  0.009846  0.049656
# HFEMS.MRPAP.01.SH01.PL003.02.HZ  0.010009  0.045989
# HFEMS.MRPAP.01.SH01.PL003.01.HZ  0.009846  0.049656
# HFEMS.MRPAP.01.SH01.PL003.02.HZ  0.010009  0.045989
# HFEMS.MRPAP.01.SH01.PL003.01.HZ  0.009846  0.049656
# ...

# %%
temp = pd.DataFrame()
for i in range(len(list(df_spearmanr['월'].unique()))):
    pivot = correlation(i+1)
    temp = pd.concat([temp, pivot])
