# %%
# %config Completer.use_jedi = False
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pprint
import datetime
import torch
from pyarrow import csv
import os.path
import matplotlib.pyplot as plt
import seaborn as sns
import os
from tqdm import notebook
import scipy.stats as stats
from sklearn.preprocessing import MinMaxScaler
os.environ['KMP_DUPLICATE_LIB_OK']='True'

from IPython.core.display import display, HTML
display(HTML("<style>.container {width:95% !important;}</style>")) #셀 사이즈 조절
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12580\2594418531.py:19: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container {width:95% !important;}</style>

# %%
df = pd.read_csv('C:/Users/USER/etri_csv/1/0_result/DataSet(MES,QCS,Power).csv')

# %% [markdown]
# 사용할 태그

# %%
tags_Power = [
 'HFEMS.MRPAP.01.SH01.PL003.01.A_R',
 'HFEMS.MRPAP.01.SH01.PL003.01.A_S',
 'HFEMS.MRPAP.01.SH01.PL003.01.A_T',
 'HFEMS.MRPAP.01.SH01.PL003.01.HZ',
 'HFEMS.MRPAP.01.SH01.PL003.01.KVARH',
 'HFEMS.MRPAP.01.SH01.PL003.01.KW',
 'HFEMS.MRPAP.01.SH01.PL003.01.KWH',
 'HFEMS.MRPAP.01.SH01.PL003.01.PF',
 'HFEMS.MRPAP.01.SH01.PL003.01.VA',
 'HFEMS.MRPAP.01.SH01.PL003.01.VAR',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_LL_R',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_LL_S',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_LL_T',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_R',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_S',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_T',
 'HFEMS.MRPAP.01.SH01.PL003.02.A_R',
 'HFEMS.MRPAP.01.SH01.PL003.02.A_S',
 'HFEMS.MRPAP.01.SH01.PL003.02.A_T',
 'HFEMS.MRPAP.01.SH01.PL003.02.HZ',
 'HFEMS.MRPAP.01.SH01.PL003.02.KVARH',
 'HFEMS.MRPAP.01.SH01.PL003.02.KW',
 'HFEMS.MRPAP.01.SH01.PL003.02.KWH',
 'HFEMS.MRPAP.01.SH01.PL003.02.PF',
 'HFEMS.MRPAP.01.SH01.PL003.02.VA',
 'HFEMS.MRPAP.01.SH01.PL003.02.VAR',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_LL_R',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_LL_S',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_LL_T',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_R',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_S',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_T',
 'HFEMS.MRPAP.01.SH01.PL003.03.A_R',
 'HFEMS.MRPAP.01.SH01.PL003.03.A_S',
 'HFEMS.MRPAP.01.SH01.PL003.03.A_T',
 'HFEMS.MRPAP.01.SH01.PL003.03.HZ',
 'HFEMS.MRPAP.01.SH01.PL003.03.KVARH',
 'HFEMS.MRPAP.01.SH01.PL003.03.KW',
 'HFEMS.MRPAP.01.SH01.PL003.03.KWH',
 'HFEMS.MRPAP.01.SH01.PL003.03.PF',
 'HFEMS.MRPAP.01.SH01.PL003.03.VA',
 'HFEMS.MRPAP.01.SH01.PL003.03.VAR',
 'HFEMS.MRPAP.01.SH01.PL003.03.V_LL_R',
 'HFEMS.MRPAP.01.SH01.PL003.03.V_LL_S',
 'HFEMS.MRPAP.01.SH01.PL003.03.V_LL_T',
 'HFEMS.MRPAP.01.SH01.PL003.03.V_R',
 'HFEMS.MRPAP.01.SH01.PL003.03.V_S',
 'HFEMS.MRPAP.01.SH01.PL003.03.V_T',
 'HFEMS.MRPAP.01.SH01.PL003.04.A_R',
 'HFEMS.MRPAP.01.SH01.PL003.04.A_S',
 'HFEMS.MRPAP.01.SH01.PL003.04.A_T',
 'HFEMS.MRPAP.01.SH01.PL003.04.HZ',
 'HFEMS.MRPAP.01.SH01.PL003.04.KVARH',
 'HFEMS.MRPAP.01.SH01.PL003.04.KW',
 'HFEMS.MRPAP.01.SH01.PL003.04.KWH',
 'HFEMS.MRPAP.01.SH01.PL003.04.PF',
 'HFEMS.MRPAP.01.SH01.PL003.04.VA',
 'HFEMS.MRPAP.01.SH01.PL003.04.VAR',
 'HFEMS.MRPAP.01.SH01.PL003.04.V_LL_R',
 'HFEMS.MRPAP.01.SH01.PL003.04.V_LL_S',
 'HFEMS.MRPAP.01.SH01.PL003.04.V_LL_T',
 'HFEMS.MRPAP.01.SH01.PL003.04.V_R',
 'HFEMS.MRPAP.01.SH01.PL003.04.V_S',
 'HFEMS.MRPAP.01.SH01.PL003.04.V_T',
 'HFEMS.MRPAP.01.SH01.PL003.05.A_R',
 'HFEMS.MRPAP.01.SH01.PL003.05.A_S',
 'HFEMS.MRPAP.01.SH01.PL003.05.A_T',
 'HFEMS.MRPAP.01.SH01.PL003.05.HZ',
 'HFEMS.MRPAP.01.SH01.PL003.05.KVARH',
 'HFEMS.MRPAP.01.SH01.PL003.05.KW',
 'HFEMS.MRPAP.01.SH01.PL003.05.KWH',
 'HFEMS.MRPAP.01.SH01.PL003.05.PF',
 'HFEMS.MRPAP.01.SH01.PL003.05.VA',
 'HFEMS.MRPAP.01.SH01.PL003.05.VAR',
 'HFEMS.MRPAP.01.SH01.PL003.05.V_LL_R',
 'HFEMS.MRPAP.01.SH01.PL003.05.V_LL_S',
 'HFEMS.MRPAP.01.SH01.PL003.05.V_LL_T',
 'HFEMS.MRPAP.01.SH01.PL003.05.V_R',
 'HFEMS.MRPAP.01.SH01.PL003.05.V_S',
 'HFEMS.MRPAP.01.SH01.PL003.05.V_T',
 'HFEMS.MRPAP.01.SH01.PL003.06.A_R',
 'HFEMS.MRPAP.01.SH01.PL003.06.A_S',
 'HFEMS.MRPAP.01.SH01.PL003.06.A_T',
 'HFEMS.MRPAP.01.SH01.PL003.06.HZ',
 'HFEMS.MRPAP.01.SH01.PL003.06.KVARH',
 'HFEMS.MRPAP.01.SH01.PL003.06.KW',
 'HFEMS.MRPAP.01.SH01.PL003.06.KWH',
 'HFEMS.MRPAP.01.SH01.PL003.06.PF',
 'HFEMS.MRPAP.01.SH01.PL003.06.VA',
 'HFEMS.MRPAP.01.SH01.PL003.06.VAR',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_LL_R',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_LL_S',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_LL_T',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_R',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_S',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_T'
 ]

# %%
tags_QCS=['320PIC7509:me',
    '320PIC7510:me',
    '320PIC7511:me',
    'PM3-S3SC.opr:me',
    '320PIC7513:me',
    '320PIC7514:me',
    'PM3-S5SC.opr:me',
    '320PIC7533:me',
    '320PIC7544:me',
    '320PIC7505:me',
    '320PIC7506:me',
    '320PIC7507:me',
    '320PIC7508:me',
    '320PDC7516:me',
    '320PDC7518:me',
    '320PDV7519.1:av',
    '320PDC7520:me',
    '320TIA7504:av',
    '320TIA7530:av',
    '320TIA7541:av',
    '320TIC7523:me',
    '320TIC0004:me',
    '320TIC7540:me',
    '320TIC7545:me',
    'PM3_BASIS_WEIGHT_SP',
    'PM3_BASIS_WEIGHT_SP2',
    'PM3_MOISTURE_SP',
    'PM3_MOISTURE_SP2',
    '329-GIC1002:me',
    '329-PIC7030.A:me',
    '329-PIC7030.B:me',
    '320-PIC0501:me',
    'PM3_WIRE_SPEED',
    'PM3_ASH_PV',
    'PM3_STOCK_CONSISTENCY_PV',
    'PM3_STOCK_FLOW_PV',
    'PM3-JWC1.opr:me',
    'PM3-TSF1.opr:me',
    'PM3-RLS1.opr:me',
    'PM3-TASH.opr:me',
    '320LIC7524:me',
    '320LIC7525:me',
    '320LIC7526:me',
    '320LIC7527:me',
    '320LIC7528:me',
    '320LIC7529:me',
    '320LIC7537:me',
    '320FIA7531:av']

# %% [markdown]
# ### 노이즈 전상관계수

# %%
condition_1 = ((df['지종']=='네오★백상')&(df['평량']==100.0))
condition_2 = ((df['지종']=='네오★스노우화이트기지')&(df['평량']==73.0))
condition_3 = ((df['지종']=='네오★스노우화이트기지')&(df['평량']==77.0))
condition_4 = ((df['지종']=='네오★스노우화이트기지')&(df['평량']==62.0))
condition_5 = ((df['지종']=='네오★아트 R10기지')&(df['평량']==77.0))
condition_6 = ((df['지종']=='네오★라벨기지')&(df['평량']==67.0))
condition_7 = ((df['지종']=='네오★스노우화이트 R10기지')&(df['평량']==67.0))
condition_8 = ((df['지종']=='네오★아트기지')&(df['평량']==62.0))
condition_9 = ((df['지종']=='네오★아트기지')&(df['평량']==73.0))

# %%
condition_legend=['네오★백상(100.0)', 
                  '네오★스노우화이트기지(73.0)',
                  '네오★스노우화이트기지(77.0)',
                  '네오★스노우화이트기지(62.0)',
                  '네오★아트 R10기지(77.0)', 
                  '네오★라벨기지(67.0)',
                  '네오★스노우화이트 R10기지(67.0)',
                  '네오★아트기지(62.0)', 
                  '네오★아트기지(73.0)',
                  ]

# %%
conditions=condition_1 | condition_2 | condition_3 | condition_4 | condition_5 | condition_6 | condition_7 | condition_8 | condition_9

# %%
tags = ['작업시작시간','지절','지종','평량']+tags_Power+tags_QCS
#tags = ['작업시작시간','지절','지종','평량']+tags_QCS


# remv = ['HFEMS.MRPAP.01.SH01.PL003.06.V_R', 'HFEMS.MRPAP.01.SH01.PL003.06.V_S', 'HFEMS.MRPAP.01.SH01.PL003.06.V_T', '320PIC7524:me', '320PDV7522.1:av', '320HIC7501:av', '320PIC7524:me.1', '320LIC7529:me.1', '320LIC7528:me.1', '320LIC7527:me.1', '320LIC7526:me.1', '320LIC7525:me.1', '320FIA7535:av'] 

# for i in remv:
#     tags.remove(i)

# %%
df_temp = df[conditions][tags]

# %%
for index,condition in enumerate([condition_1,condition_2,condition_3,condition_4,condition_5,condition_6,condition_7,condition_8,condition_9 ]):
    df_temp.loc[condition,['지종']]=index

# %%
list(df_temp['지종'].unique())
# Out:
# [8, 4, 5, 3, 6, 1, 2, 0, 7]

# %%
target=list(df_temp.columns)

# %%
target
# Out:
# ['작업시작시간',
#  '지절',
#  '지종',
#  '평량',
#  'HFEMS.MRPAP.01.SH01.PL003.01.A_R',
#  'HFEMS.MRPAP.01.SH01.PL003.01.A_S',
#  'HFEMS.MRPAP.01.SH01.PL003.01.A_T',
#  'HFEMS.MRPAP.01.SH01.PL003.01.HZ',
#  'HFEMS.MRPAP.01.SH01.PL003.01.KVARH',
#  'HFEMS.MRPAP.01.SH01.PL003.01.KW',
#  'HFEMS.MRPAP.01.SH01.PL003.01.KWH',
#  'HFEMS.MRPAP.01.SH01.PL003.01.PF',
#  'HFEMS.MRPAP.01.SH01.PL003.01.VA',
#  'HFEMS.MRPAP.01.SH01.PL003.01.VAR',
#  'HFEMS.MRPAP.01.SH01.PL003.01.V_LL_R',
#  'HFEMS.MRPAP.01.SH01.PL003.01.V_LL_S',
#  'HFEMS.MRPAP.01.SH01.PL003.01.V_LL_T',
#  'HFEMS.MRPAP.01.SH01.PL003.01.V_R',
#  'HFEMS.MRPAP.01.SH01.PL003.01.V_S',
#  'HFEMS.MRPAP.01.SH01.PL003.01.V_T',
#  'HFEMS.MRPAP.01.SH01.PL003.02.A_R',
#  'HFEMS.MRPAP.01.SH01.PL003.02.A_S',
#  'HFEMS.MRPAP.01.SH01.PL003.02.A_T',
#  'HFEMS.MRPAP.01.SH01.PL003.02.HZ',
#  'HFEMS.MRPAP.01.SH01.PL003.02.KVARH',
#  'HFEMS.MRPAP.01.SH01.PL003.02.KW',
#  'HFEMS.MRPAP.01.SH01.PL003.02.KWH',
#  'HFEMS.MRPAP.01.SH01.PL003.02.PF',
#  'HFEMS.MRPAP.01.SH01.PL003.02.VA',
#  'HFEMS.MRPAP.01.SH01.PL003.02.VAR',
#  'HFEMS.MRPAP.01.SH01.PL003.02.V_LL_R',
#  'HFEMS.MRPAP.01.SH01.PL003.02.V_LL_S',
#  'HFEMS.MRPAP.01.SH01.PL003.02.V_LL_T',
#  'HFEMS.MRPAP.01.SH01.PL003.02.V_R',
#  'HFEMS.MRPAP.01.SH01.PL003.02.V_S',
#  'HFEMS.MRPAP.01.SH01.PL003.02.V_T',
#  'HFEMS.MRPAP.01.SH01.PL003.03.A_R',
#  'HFEMS.MRPAP.01.SH01.PL003.03.A_S',
#  'HFEMS.MRPAP.01.SH01.PL003.03.A_T',
#  'HFEMS.MRPAP.01.SH01.PL003.03.HZ',
#  'HFEMS.MRPAP.01.SH01.PL003.03.KVARH',
#  'HFEMS.MRPAP.01.SH01.PL003.03.KW',
#  'HFEMS.MRPAP.01.SH01.PL003.03.KWH',
#  'HFEMS.MRPAP.01.SH01.PL003.03.PF',
#  'HFEMS.MRPAP.01.SH01.PL003.03.VA',
#  'HFEMS.MRPAP.01.SH01.PL003.03.VAR',
#  'HFEMS.MRPAP.01.SH01.PL003.03.V_LL_R',
#  'HFEMS.MRPAP.01.SH01.PL003.03.V_LL_S',
#  'HFEMS.MRPAP.01.SH01.PL003.03.V_LL_T',
#  'HFEMS.MRPAP.01.SH01.PL003.03.V_R',
#  'HFEMS.MRPAP.01.SH01.PL003.03.V_S',
#  'HFEMS.MRPAP.01.SH01.PL003.03.V_T',
#  'HFEMS.MRPAP.01.SH01.PL003.04.A_R',
#  'HFEMS.MRPAP.01.SH01.PL003.04.A_S',
#  'HFEMS.MRPAP.01.SH01.PL003.04.A_T',
#  'HFEMS.MRPAP.01.SH01.PL003.04.HZ',
#  'HFEMS.MRPAP.01.SH01.PL003.04.KVARH',
#  'HFEMS.MRPAP.01.SH01.PL003.04.KW',
#  'HFEMS.MRPAP.01.SH01.PL003.04.KWH',
#  'HFEMS.MRPAP.01.SH01.PL003.04.PF',
#  'HFEMS.MRPAP.01.SH01.PL003.04.VA',
#  'HFEMS.MRPAP.01.SH01.PL003.04.VAR',
#  'HFEMS.MRPAP.01.SH01.PL003.04.V_LL_R',
#  'HFEMS.MRPAP.01.SH01.PL003.04.V_LL_S',
#  'HFEMS.MRPAP.01.SH01.PL003.04.V_LL_T',
#  'HFEMS.MRPAP.01.SH01.PL003.04.V_R',
#  'HFEMS.MRPAP.01.SH01.PL003.04.V_S',
#  'HFEMS.MRPAP.01.SH01.PL003.04.V_T',
#  'HFEMS.MRPAP.01.SH01.PL003.05.A_R',
#  'HFEMS.MRPAP.01.SH01.PL003.05.A_S',
#  'HFEMS.MRPAP.01.SH01.PL003.05.A_T',
#  'HFEMS.MRPAP.01.SH01.PL003.05.HZ',
#  'HFEMS.MRPAP.01.SH01.PL003.05.KVARH',
#  'HFEMS.MRPAP.01.SH01.PL003.05.KW',
#  'HFEMS.MRPAP.01.SH01.PL003.05.KWH',
#  'HFEMS.MRPAP.01.SH01.PL003.05.PF',
#  'HFEMS.MRPAP.01.SH01.PL003.05.VA',
#  'HFEMS.MRPAP.01.SH01.PL003.05.VAR',
#  'HFEMS.MRPAP.01.SH01.PL003.05.V_LL_R',
#  'HFEMS.MRPAP.01.SH01.PL003.05.V_LL_S',
#  'HFEMS.MRPAP.01.SH01.PL003.05.V_LL_T',
#  'HFEMS.MRPAP.01.SH01.PL003.05.V_R',
#  'HFEMS.MRPAP.01.SH01.PL003.05.V_S',
#  'HFEMS.MRPAP.01.SH01.PL003.05.V_T',
#  'HFEMS.MRPAP.01.SH01.PL003.06.A_R',
#  'HFEMS.MRPAP.01.SH01.PL003.06.A_S',
#  'HFEMS.MRPAP.01.SH01.PL003.06.A_T',
#  'HFEMS.MRPAP.01.SH01.PL003.06.HZ',
#  'HFEMS.MRPAP.01.SH01.PL003.06.KVARH',
#  'HFEMS.MRPAP.01.SH01.PL003.06.KW',
#  'HFEMS.MRPAP.01.SH01.PL003.06.KWH',
#  'HFEMS.MRPAP.01.SH01.PL003.06.PF',
#  'HFEMS.MRPAP.01.SH01.PL003.06.VA',
#  'HFEMS.MRPAP.01.SH01.PL003.06.VAR',
#  'HFEMS.MRPAP.01.SH01.PL003.06.V_LL_R',
#  'HFEMS.MRPAP.01.SH01.PL003.06.V_LL_S',
#  'HFEMS.MRPAP.01.SH01.PL003.06.V_LL_T',
#  'HFEMS.MRPAP.01.SH01.PL003.06.V_R',
#  'HFEMS.MRPAP.01.SH01.PL003.06.V_S',
#  'HFEMS.MRPAP.01.SH01.PL003.06.V_T',
#  '320PIC7509:me',
#  '320PIC7510:me',
#  '320PIC7511:me',
#  'PM3-S3SC.opr:me',
#  '320PIC7513:me',
#  '320PIC7514:me',
#  'PM3-S5SC.opr:me',
#  '320PIC7533:me',
#  '320PIC7544:me',
#  '320PIC7505:me',
#  '320PIC7506:me',
#  '320PIC7507:me',
#  '320PIC7508:me',
#  '320PDC7516:me',
#  '320PDC7518:me',
#  '320PDV7519.1:av',
#  '320PDC7520:me',
#  '320TIA7504:av',
#  '320TIA7530:av',
#  '320TIA7541:av',
#  '320TIC7523:me',
#  '320TIC0004:me',
#  '320TIC7540:me',
#  '320TIC7545:me',
#  'PM3_BASIS_WEIGHT_SP',
#  'PM3_BASIS_WEIGHT_SP2',
#  'PM3_MOISTURE_SP',
#  'PM3_MOISTURE_SP2',
#  '329-GIC1002:me',
#  '329-PIC7030.A:me',
#  '329-PIC7030.B:me',
#  '320-PIC0501:me',
#  'PM3_WIRE_SPEED',
#  'PM3_ASH_PV',
#  'PM3_STOCK_CONSISTENCY_PV',
#  'PM3_STOCK_FLOW_PV',
#  'PM3-JWC1.opr:me',
#  'PM3-TSF1.opr:me',
#  'PM3-RLS1.opr:me',
#  'PM3-TASH.opr:me',
#  '320LIC7524:me',
#  '320LIC7525:me',
#  '320LIC7526:me',
#  '320LIC7527:me',
#  '320LIC7528:me',
#  '320LIC7529:me',
#  '320LIC7537:me',
#  '320FIA7531:av']

# %%
#base
y = df_temp.loc[:, '지절'].values
temp=pd.DataFrame(columns=['Corr', 'P-val'])

tags = target
tags.remove('지절')

for item in tags:
    X = df_temp.loc[:, item].values
    if (stats.spearmanr(X,y)[1]<0.05) and (stats.spearmanr(X,y)[1]>0.001):
        temp.loc[item] = [stats.spearmanr(X, y)[0], stats.spearmanr(X, y)[1]]


temp['Corr_abs'] = abs(temp['Corr'])

temp.sort_values(by = 'Corr_abs', ascending=False)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\scipy\stats\stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
#                                       Corr     P-val  Corr_abs
# HFEMS.MRPAP.01.SH01.PL003.03.A_S  0.321882  0.001653  0.321882
# HFEMS.MRPAP.01.SH01.PL003.03.VAR  0.309428  0.002544  0.309428
# HFEMS.MRPAP.01.SH01.PL003.02.VAR  0.288352  0.005064  0.288352
# HFEMS.MRPAP.01.SH01.PL003.02.A_T  0.280688  0.006425  0.280688
# HFEMS.MRPAP.01.SH01.PL003.02.A_S  0.278772  0.006812  0.278772
# HFEMS.MRPAP.01.SH01.PL003.02.VA   0.277814  0.007013  0.277814
# HFEMS.MRPAP.01.SH01.PL003.02.A_R  0.272067  0.008335  0.272067
# HFEMS.MRPAP.01.SH01.PL003.02.KW   0.217462  0.036270  0.217462

# %% [markdown]
# MinMaxScaler

# %%
tags=target

# %%
tags.remove('지종')
tags.remove('평량')

# %%
from sklearn.preprocessing import StandardScaler

scaler = MinMaxScaler()
scaler.fit(df_temp[tags]) # X scaler 생성
df_temp[tags] = scaler.transform(df_temp[tags])   # 스케일링 적용
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [225], in <cell line: 4>()
#       1 from sklearn.preprocessing import StandardScaler
#       3 scaler = MinMaxScaler()
# ----> 4 scaler.fit(df_temp[tags]) # X scaler 생성
#       5 df_temp[tags] = scaler.transform(df_temp[tags])
#
# File ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:416, in MinMaxScaler.fit(self, X, y)
#     414 # Reset internal state before fitting
#     415 self._reset()
# --> 416 return self.partial_fit(X, y)
#
# File ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:453, in MinMaxScaler.partial_fit(self, X, y)
#     447     raise TypeError(
#     448         "MinMaxScaler does not support sparse input. "
#     449         "Consider using MaxAbsScaler instead."
#     450     )
#     452 first_pass = not hasattr(self, "n_samples_seen_")
# --> 453 X = self._validate_data(
#     454     X,
#     455     reset=first_pass,
#     456     estimator=self,
#     457     dtype=FLOAT_DTYPES,
#     458     force_all_finite="allow-nan",
#     459 )
#     461 data_min = np.nanmin(X, axis=0)
#     462 data_max = np.nanmax(X, axis=0)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:566, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     564     raise ValueError("Validation should be done on X, y or both.")
#     565 elif not no_val_X and no_val_y:
# --> 566     X = check_array(X, **check_params)
#     567     out = X
#     568 elif no_val_X and not no_val_y:
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:746, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744         array = array.astype(dtype, casting="unsafe", copy=False)
#     745     else:
# --> 746         array = np.asarray(array, order=order, dtype=dtype)
#     747 except ComplexWarning as complex_warning:
#     748     raise ValueError(
#     749         "Complex data not supported\n{}\n".format(array)
#     750     ) from complex_warning
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:2064, in NDFrame.__array__(self, dtype)
#    2063 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2064     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: '2022-03-05 19:15:00'

# %% [markdown]
# MinMaxScaler 후 상관분석

# %%
df_temp.columns
# Out:
# Index(['작업시작시간', '지절', '지종', '평량', 'HFEMS.MRPAP.01.SH01.PL003.01.A_R',
#        'HFEMS.MRPAP.01.SH01.PL003.01.A_S', 'HFEMS.MRPAP.01.SH01.PL003.01.A_T',
#        'HFEMS.MRPAP.01.SH01.PL003.01.HZ', 'HFEMS.MRPAP.01.SH01.PL003.01.KVARH',
#        'HFEMS.MRPAP.01.SH01.PL003.01.KW',
#        ...
#        'PM3-RLS1.opr:me', 'PM3-TASH.opr:me', '320LIC7524:me', '320LIC7525:me',
#        '320LIC7526:me', '320LIC7527:me', '320LIC7528:me', '320LIC7529:me',
#        '320LIC7537:me', '320FIA7531:av'],
#       dtype='object', length=146)

# %%
target = list(df_temp.columns)

# %%
#base
y = df_temp.loc[:, '지절'].values
temp=pd.DataFrame(columns=['Corr', 'P-val'])

tags = target
tags.remove('지절')

for item in tags:
    X = df_temp.loc[:, item].values
    if (stats.spearmanr(X,y)[1]<0.05) and (stats.spearmanr(X,y)[1]>0.001):
        temp.loc[item] = [stats.spearmanr(X, y)[0], stats.spearmanr(X, y)[1]]


temp['Corr_abs'] = abs(temp['Corr'])

temp.sort_values(by = 'Corr_abs', ascending=False)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\scipy\stats\stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
#                                         Corr     P-val  Corr_abs
# 320TIA7541:av                      -0.092678  0.002573  0.092678
# HFEMS.MRPAP.01.SH01.PL003.02.HZ     0.087403  0.004478  0.087403
# PM3-TASH.opr:me                     0.087168  0.004587  0.087168
# 320TIA7530:av                       0.082788  0.007108  0.082788
# HFEMS.MRPAP.01.SH01.PL003.01.HZ     0.082676  0.007187  0.082676
# PM3-S3SC.opr:me                     0.079352  0.009890  0.079352
# PM3-JWC1.opr:me                     0.076460  0.012942  0.076460
# HFEMS.MRPAP.01.SH01.PL003.04.HZ     0.076072  0.013409  0.076072
# HFEMS.MRPAP.01.SH01.PL003.05.HZ     0.074690  0.015197  0.074690
# 320TIC7545:me                       0.074062  0.016077  0.074062
# 320LIC7527:me                      -0.071799  0.019626  0.071799
# 320PIC7506:me                       0.071560  0.020037  0.071560
# HFEMS.MRPAP.01.SH01.PL003.01.KVARH  0.067006  0.029457  0.067006
# HFEMS.MRPAP.01.SH01.PL003.03.HZ     0.065798  0.032520  0.065798
# 329-GIC1002:me                      0.065035  0.034589  0.065035

# %% [markdown]
# pct_change 후 스케일러

# %%
target.remove('지절')
target.remove('평량')
target.remove('지종')

# %%
temp_scaler = df_temp[target].pct_change(periods=1)

# %%
temp_scaler.drop(88, inplace=True)

# %%
temp_scaler.loc[:,['지절','지종','평량']] = df_temp.loc[:,['지절','지종','평량']]

# %% [markdown]
# pct_change 후 상관계수

# %%
#base
y = temp_scaler.loc[:, '지절'].values
temp=pd.DataFrame(columns=['Corr', 'P-val'])

tags = list(temp_scaler.columns)
tags.remove('지절')

for item in tags:
    X = temp_scaler.loc[:, item].values
    if (stats.spearmanr(X,y)[1]<0.05) and (stats.spearmanr(X,y)[1]>0.001):
        temp.loc[item] = [stats.spearmanr(X, y)[0], stats.spearmanr(X, y)[1]]


temp['Corr_abs'] = abs(temp['Corr'])
temp=temp.sort_values(by = 'Corr_abs', ascending=False)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\scipy\stats\stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())

# %%
target = list(temp.index)

# %%
target
# Out:
# ['320TIA7530:av',
#  '320TIC7545:me',
#  'HFEMS.MRPAP.01.SH01.PL003.01.PF',
#  'HFEMS.MRPAP.01.SH01.PL003.05.VAR',
#  'PM3-JWC1.opr:me',
#  'HFEMS.MRPAP.01.SH01.PL003.01.KW',
#  'HFEMS.MRPAP.01.SH01.PL003.05.VA',
#  'PM3-S3SC.opr:me',
#  'HFEMS.MRPAP.01.SH01.PL003.05.KW',
#  'HFEMS.MRPAP.01.SH01.PL003.01.A_S',
#  '320PIC7514:me',
#  'HFEMS.MRPAP.01.SH01.PL003.01.A_T',
#  '320PIC7506:me',
#  'PM3_ASH_PV',
#  'HFEMS.MRPAP.01.SH01.PL003.01.VA',
#  '320PDC7518:me',
#  '320LIC7528:me',
#  'HFEMS.MRPAP.01.SH01.PL003.05.A_R',
#  '320LIC7527:me',
#  'PM3_WIRE_SPEED']

# %%
temp_scaler['320PIC7514:me'].plot()
# Out:
# <AxesSubplot:>

# %%
temp_scaler
# Out:
#       HFEMS.MRPAP.01.SH01.PL003.01.A_R  HFEMS.MRPAP.01.SH01.PL003.01.A_S  \
# 89                            0.003501                          0.003638
# 90                            0.003012                          0.001755
# 91                           -0.000191                         -0.001111
# 92                           -0.001476                          0.000349
# 93                           -0.001260                         -0.002066
# ...                                ...                               ...
# 3194                         -0.010142                         -0.010987
# 3195                          0.014721                          0.017055
# 3196                         -0.052618                         -0.055647
# 3197                         -0.019446                         -0.013749
# 3198                          0.007158                          0.007424
#
#       HFEMS.MRPAP.01.SH01.PL003.01.A_T  HFEMS.MRPAP.01.SH01.PL003.01.HZ  \
# 89                            0.006587                         0.000260
# 90                            0.001764                        -0.000055
# 91                           -0.001368                         0.000022
# 92                            0.000388                         0.000114
# 93                           -0.001315                         0.000082
# ...                                ...                              ...
# 3194                         -0.008681                        -0.000013
# 3195                          0.019381                        -0.000705
# 3196                         -0.055381                         0.000720
# 3197                         -0.021219                        -0.000287
# 3198                          0.001916                        -0.000057
#
#       HFEMS.MRPAP.01.SH01.PL003.01.KVARH  HFEMS.MRPAP.01.SH01.PL003.01.KW  \
# 89                                   0.0                         0.037569
# 90                                   0.0                         0.001484
# 91                                   0.0                        -0.003400
# 92                                   0.0                         0.002347
# 93                                   0.0                         0.000885
# ...                                  ...                              ...
# 3194                                 0.0                        -0.011862
# 3195                                 0.0                         0.017368
# 3196                                 0.0                        -0.057094
# 3197                                 0.0                        -0.020910
# 3198                                 0.0                        -0.066323
#
#       HFEMS.MRPAP.01.SH01.PL003.01.KWH  HFEMS.MRPAP.01.SH01.PL003.01.PF  \
# 89                            0.000003                         0.030361
# 90                            0.000003                         0.000893
# 91                            0.000000                        -0.000051
# 92                            0.000000                        -0.000395
# 93                            0.000000                        -0.001415
# ...                                ...                              ...
# 3194                          0.000000                        -0.001182
# 3195                          0.000000                         0.001423
# 3196                          0.000000                        -0.003878
# 3197                          0.000011                        -0.001056
# 3198                          0.000312                        -0.062678
#
#       HFEMS.MRPAP.01.SH01.PL003.01.VA  HFEMS.MRPAP.01.SH01.PL003.01.VAR  ...  \
# 89                           0.005437                         -0.030083  ...
# 90                           0.000588                         -0.004034  ...
# 91                          -0.003357                         -0.003140  ...
# 92                           0.002749                          0.004796  ...
# 93                           0.002298                          0.009612  ...
# ...                               ...                               ...  ...
# 3194                        -0.010694                          0.021008  ...
# 3195                         0.015931                         -0.022684  ...
# 3196                        -0.053427                          0.044521  ...
# 3197                        -0.019884                          0.003385  ...
# 3198                        -0.003890                          0.901560  ...
#
#       320LIC7525:me  320LIC7526:me  320LIC7527:me  320LIC7528:me  \
# 89        -0.000217   7.520036e-05       0.000239      -0.000046
# 90        -0.000217   7.519471e-05       0.000239      -0.000046
# 91        -0.000217   7.518905e-05       0.000239      -0.000046
# 92        -0.000217   7.518340e-05       0.000239      -0.000046
# 93        -0.000217   7.517775e-05       0.000239      -0.000046
# ...             ...            ...            ...            ...
# 3194      -0.000031   3.043277e-07      -0.000168      -0.000083
# 3195      -0.000031   3.043276e-07      -0.000168      -0.000083
# 3196      -0.000031   3.043275e-07      -0.000168      -0.000083
# 3197      -0.008617   8.460301e-05      -0.046850      -0.023016
# 3198      -0.075612   2.016911e-03      -0.471764      -0.230259
#
#       320LIC7529:me  320LIC7537:me  320FIA7531:av   지절  지종     평량
# 89         0.000059       0.000158      -0.000060  0.0   0  100.0
# 90         0.000059       0.000158      -0.000060  0.0   0  100.0
# 91         0.000059       0.000158      -0.000060  0.0   0  100.0
# 92         0.000059       0.000158      -0.000060  0.0   0  100.0
# 93         0.000059       0.000158      -0.000060  0.0   0  100.0
# ...             ...            ...            ...  ...  ..    ...
# 3194      -0.000076      -0.000178      -0.000009  1.0   0  100.0
# 3195      -0.000076      -0.000178      -0.000009  1.0   0  100.0
# 3196      -0.000076      -0.000178      -0.000009  1.0   0  100.0
# 3197      -0.021221      -0.049630      -0.002588  1.0   3   62.0
# 3198      -0.215749      -0.444525      -0.061866  1.0   7   62.0
#
# [1055 rows x 145 columns]

# %%
for t in target : 

    temp = df[t]
    temp=temp.reset_index()

    from datetime import datetime, timedelta

    start = df_sheet2['Loss 시작']+timedelta(minutes=-20)
    end = df_sheet2['종료']+timedelta(minutes=+20)
    
    
    plt.figure(figsize=(20,8), constrained_layout = True)
    for i in range(len(start)):
        time = ((temp['작업시작시간'] > start[i]) & (temp['작업시작시간'] < end[i]))
        temp_V_LL = temp[time]



        plt.subplot(2,4,i+1)
        plt.plot(temp_V_LL['작업시작시간'],temp_V_LL[t])
        plt.axvspan(df_sheet2.loc[i,'Loss 시작'], df_sheet2.loc[i,'종료'], color='yellow', alpha=0.5, hatch='///')

        plt.suptitle(t, size=20)
        plt.xticks(rotation=45)
        plt.grid()

    plt.show()

# %%
temp_scaler['320TIA7530:av'].plot()
# Out:
# <AxesSubplot:>
