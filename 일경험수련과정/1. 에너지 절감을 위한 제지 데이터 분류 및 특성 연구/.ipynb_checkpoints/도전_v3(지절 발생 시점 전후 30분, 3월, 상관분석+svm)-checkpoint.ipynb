# %%
# %config Completer.use_jedi = False
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pprint
import datetime
import torch
from pyarrow import csv
import os.path
import matplotlib.pyplot as plt
import seaborn as sns
import os
from tqdm import notebook
import scipy.stats as stats
from datetime import datetime, timedelta
os.environ['KMP_DUPLICATE_LIB_OK']='True'

from IPython.core.display import display, HTML
display(HTML("<style>.container {width:95% !important;}</style>")) #셀 사이즈 조절
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13052\4113253724.py:19: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container {width:95% !important;}</style>

# %%
df = pd.read_csv('C:/Users/USER/etri_csv/논문/논문자료_v1.csv')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13052\428708869.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:/Users/USER/etri_csv/논문/논문자료_v1.csv')

# %% [markdown]
# 사용할 태그

# %%
tags_Power = [
 'HFEMS.MRPAP.01.SH01.PL003.01.A_R',
 'HFEMS.MRPAP.01.SH01.PL003.01.A_S',
 'HFEMS.MRPAP.01.SH01.PL003.01.A_T',
 'HFEMS.MRPAP.01.SH01.PL003.01.HZ',
 'HFEMS.MRPAP.01.SH01.PL003.01.KVARH',
 'HFEMS.MRPAP.01.SH01.PL003.01.KW',
 'HFEMS.MRPAP.01.SH01.PL003.01.KWH',
 'HFEMS.MRPAP.01.SH01.PL003.01.PF',
 'HFEMS.MRPAP.01.SH01.PL003.01.VA',
 'HFEMS.MRPAP.01.SH01.PL003.01.VAR',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_LL_R',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_LL_S',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_LL_T',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_R',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_S',
 'HFEMS.MRPAP.01.SH01.PL003.01.V_T',
 'HFEMS.MRPAP.01.SH01.PL003.02.A_R',
 'HFEMS.MRPAP.01.SH01.PL003.02.A_S',
 'HFEMS.MRPAP.01.SH01.PL003.02.A_T',
 'HFEMS.MRPAP.01.SH01.PL003.02.HZ',
 'HFEMS.MRPAP.01.SH01.PL003.02.KVARH',
 'HFEMS.MRPAP.01.SH01.PL003.02.KW',
 'HFEMS.MRPAP.01.SH01.PL003.02.KWH',
 'HFEMS.MRPAP.01.SH01.PL003.02.PF',
 'HFEMS.MRPAP.01.SH01.PL003.02.VA',
 'HFEMS.MRPAP.01.SH01.PL003.02.VAR',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_LL_R',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_LL_S',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_LL_T',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_R',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_S',
 'HFEMS.MRPAP.01.SH01.PL003.02.V_T',
 'HFEMS.MRPAP.01.SH01.PL003.03.A_R',
 'HFEMS.MRPAP.01.SH01.PL003.03.A_S',
 'HFEMS.MRPAP.01.SH01.PL003.03.A_T',
 'HFEMS.MRPAP.01.SH01.PL003.03.HZ',
 'HFEMS.MRPAP.01.SH01.PL003.06.HZ',
 'HFEMS.MRPAP.01.SH01.PL003.06.KVARH',
 'HFEMS.MRPAP.01.SH01.PL003.06.KW',
 'HFEMS.MRPAP.01.SH01.PL003.06.KWH',
 'HFEMS.MRPAP.01.SH01.PL003.06.PF',
 'HFEMS.MRPAP.01.SH01.PL003.06.VA',
 'HFEMS.MRPAP.01.SH01.PL003.06.VAR',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_LL_R',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_LL_S',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_LL_T',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_R',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_S',
 'HFEMS.MRPAP.01.SH01.PL003.06.V_T'
 ]

# %%
tags_QCS=[
    '320PIC7509:me',
 '320PIC7510:me',
 '320PIC7511:me',
 'PM3-S3SC.opr:me',
 '320PIC7513:me',
 '320PIC7514:me',
 'PM3-S5SC.opr:me',
 '320PIC7524:me',
 '320PIC7533:me',
 '320PIC7544:me',
 '320PIC7505:me',
 '320PIC7506:me',
 '320PIC7507:me',
 '320PIC7508:me',
 '320PDC7516:me',
 '320PDC7518:me',
 '320PDV7519.1:av',
 '320PDC7520:me',
 '320PDV7522.1:av',
 '320HIC7501:av',
 '320TIA7504:av',
 '320TIA7530:av',
 '320TIA7541:av',
 '320TIA7542:av',
 '320TIC7523:me',
 '320PIC7524:me.1',
 '320TIC0004:me',
 '320TIC7540:me',
 '320TIC7545:me',
 'PM3_BASIS_WEIGHT_SP',
 'PM3_BASIS_WEIGHT_SP2',
 'PM3_MOISTURE_SP',
 'PM3_MOISTURE_SP2',
 '329-GIC1002:me',
 '329-PIC7030.A:me',
 '329-PIC7030.B:me',
 '320-PIC0501:me',
 'PM3_WIRE_SPEED',
 'PM3_ASH_PV',
 'PM3_STOCK_CONSISTENCY_PV',
 'PM3_STOCK_FLOW_PV',
 'PM3-JWC1.opr:me',
 'PM3-TSF1.opr:me',
 'PM3-RLS1.opr:me',
 'PM3-TASH.opr:me',
 '320LIC7524:me',
 '320LIC7525:me',
 '320LIC7526:me',
 '320LIC7527:me',
 '320LIC7528:me',
 '320LIC7529:me',
 '320LIC7537:me',
 '320LIC7529:me.1',
 '320LIC7528:me.1',
 '320LIC7527:me.1',
 '320LIC7526:me.1',
 '320LIC7525:me.1',
 '320FIA7531:av',
 '320FIA7535:av'
]

# %%
tags_MES=['가동상태',
 '이력TYPE',
 '지절',
 '월',
 '지종',
 '평량']

# %% [markdown]
# 결측치 처리

# %%
df.set_index('작업시작시간', inplace=True)

# %%
df.index =pd.to_datetime(df.index)

# %%
df.interpolate('time', inplace=True)

# %%
df.dropna(subset=['설비'], inplace=True)

# %%
df.fillna(method='bfill',inplace=True)

# %%
df.reset_index(inplace=True)

# %% [markdown]
# 3월 지절 발생 로그

# %%
df_sheet2 = pd.read_excel('C:/Users/USER/etri_csv/1/FEMS Raw Data_220804_v2.0.xlsx', sheet_name=2, engine='openpyxl')

# %%
df_sheet2 = df_sheet2[df_sheet2['월']==202203]

# %%
df_sheet2 = df_sheet2[df_sheet2['Note'].str.contains('지절', na=False)]

# %%
df_sheet2.reset_index(drop=True, inplace=True)

# %%
df_sheet2 = df_sheet2.loc[:,['Loss 시작','종료']]

# %% [markdown]
# 3월 지절 발생 데이터(발생시점 전후 30분)

# %%
df_sheet2['Loss 시작']=df_sheet2['Loss 시작']+timedelta(minutes = -30)
df_sheet2['종료']=df_sheet2['종료']+timedelta(minutes = +30)

# %%
time1 = ((df['작업시작시간']>df_sheet2['Loss 시작'][0])&(df['작업시작시간']<df_sheet2['종료'][0]))
time2 = ((df['작업시작시간']>df_sheet2['Loss 시작'][1])&(df['작업시작시간']<df_sheet2['종료'][1]))
time3 = ((df['작업시작시간']>df_sheet2['Loss 시작'][2])&(df['작업시작시간']<df_sheet2['종료'][2]))
time4 = ((df['작업시작시간']>df_sheet2['Loss 시작'][3])&(df['작업시작시간']<df_sheet2['종료'][3]))
time5 = ((df['작업시작시간']>df_sheet2['Loss 시작'][4])&(df['작업시작시간']<df_sheet2['종료'][4]))
time6 = ((df['작업시작시간']>df_sheet2['Loss 시작'][5])&(df['작업시작시간']<df_sheet2['종료'][5]))
time7 = ((df['작업시작시간']>df_sheet2['Loss 시작'][6])&(df['작업시작시간']<df_sheet2['종료'][6]))
time8 = ((df['작업시작시간']>df_sheet2['Loss 시작'][7])&(df['작업시작시간']<df_sheet2['종료'][7]))

# %%
time = time1|time2|time3|time4|time5|time6|time7|time8

# %%
df_temp = df[time]
df_temp.reset_index(drop=True, inplace=True)

# %%
df_temp
# Out:
#                  작업시작시간     설비  가동상태 이력TYPE   지절    월  작업총시간           LOT  \
# 0   2022-03-07 00:53:00  초지3호기    생산     생산  0.0  3.0   57.0  J3M3A0116000
# 1   2022-03-07 00:54:00  초지3호기    생산     생산  0.0  3.0   57.0  J3M3A0116000
# 2   2022-03-07 00:55:00  초지3호기    생산     생산  0.0  3.0   57.0  J3M3A0116000
# 3   2022-03-07 00:56:00  초지3호기    생산     생산  0.0  3.0   57.0  J3M3A0116000
# 4   2022-03-07 00:57:00  초지3호기    생산     생산  0.0  3.0   57.0  J3M3A0116000
# ..                  ...    ...   ...    ...  ...  ...    ...           ...
# 690 2022-03-13 21:59:00  초지3호기  초출파지   초출파지  0.0  3.0   37.8  J3M3A0293000
# 691 2022-03-13 22:00:00  초지3호기  초출파지   초출파지  0.0  3.0   29.6  J3M3A0293000
# 692 2022-03-13 22:01:00  초지3호기  초출파지   초출파지  0.0  3.0   21.4  J3M3A0293000
# 693 2022-03-13 22:02:00  초지3호기  초출파지   초출파지  0.0  3.0   13.2  J3M3A0293000
# 694 2022-03-13 22:03:00  초지3호기  초출파지   초출파지  0.0  3.0    5.0  J3M3A0293000
#
#           제조번호           지종  ...  320LIC7528:me  320LIC7529:me  320LIC7537:me  \
# 0    2322193.0  네오★아트 R10기지  ...          54.70         50.390          48.91
# 1    2322193.0  네오★아트 R10기지  ...          54.70         50.430          49.02
# 2    2322193.0  네오★아트 R10기지  ...          54.70         50.550          49.13
# 3    2322193.0  네오★아트 R10기지  ...          54.70         50.670          48.69
# 4    2322193.0  네오★아트 R10기지  ...          54.70         50.610          46.91
# ..         ...          ...  ...            ...            ...            ...
# 690  1322038.0        네오★백상  ...          31.60         26.605          38.95
# 691  1322038.0        네오★백상  ...          31.53         26.570          37.09
# 692  1322038.0        네오★백상  ...          33.21         27.500          35.65
# 693  1322038.0        네오★백상  ...          35.52         28.805          34.21
# 694  1322038.0        네오★백상  ...          37.83         30.110          34.29
#
#     320LIC7529:me.1  320LIC7528:me.1 320LIC7527:me.1  320LIC7526:me.1  \
# 0            50.390            54.70       75.460000        50.700000
# 1            50.430            54.70       76.923333        48.210000
# 2            50.550            54.70       78.386667        47.010000
# 3            50.670            54.70       79.850000        47.840000
# 4            50.610            54.70       78.750000        48.030000
# ..              ...              ...             ...              ...
# 690          26.605            31.60       38.560000        48.350000
# 691          26.570            31.53       36.310000        46.105000
# 692          27.500            33.21       34.870000        43.860000
# 693          28.805            35.52       34.510000        44.436667
# 694          30.110            37.83       35.120000        45.013333
#
#      320LIC7525:me.1  320FIA7531:av 320FIA7535:av
# 0              48.91           8.44          18.0
# 1              49.65           8.35          18.0
# 2              50.06           0.05          18.0
# 3              50.18           0.04          18.0
# 4              50.67          16.56          18.0
# ..               ...            ...           ...
# 690            44.47          10.91          18.0
# 691            44.74           7.01          18.0
# 692            45.45           6.49          18.0
# 693            45.35           1.71          18.0
# 694            45.25           0.04          18.0
#
# [695 rows x 195 columns]

# %%
temp = df_temp['지종'].values+"("+df_temp['평량'].astype(str)+")"

# %%
temp.unique()
# Out:
# array(['네오★아트 R10기지(77.0)', '네오★라벨기지(67.0)', '네오★스노우화이트기지(62.0)',
#        '네오★스노우화이트기지(73.0)', '네오★스노우화이트기지(77.0)', '네오★백상(100.0)'],
#       dtype=object)

# %%
condition_1 = ((df_temp['지종']=='네오★아트 R10기지')&(df_temp['평량']==77.0))
condition_2 = ((df_temp['지종']=='네오★라벨기지')&(df_temp['평량']==67.0))
condition_3 = ((df_temp['지종']=='네오★스노우화이트기지')&(df_temp['평량']==62.0))
condition_4 = ((df_temp['지종']=='네오★스노우화이트기지')&(df_temp['평량']==73.0))
condition_5 = ((df_temp['지종']=='네오★스노우화이트기지')&(df_temp['평량']==77.0))
condition_6 = ((df_temp['지종']=='네오★백상')&(df_temp['평량']==100.0))

# %%
conditions = condition_1|condition_2|condition_3|condition_4|condition_5|condition_6

# %%
tags = ['지절','지종','평량']+tags_Power+tags_QCS

# %%
temp =
